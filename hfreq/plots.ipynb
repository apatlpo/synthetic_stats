# %% [markdown]
# # overview plots

# %%
import matplotlib.pyplot as plt

import sstats.hfreq as hf
import sstats.tseries as ts

print_figs = True

# %% [markdown]
# ---
#
# ## Low frequency signal

# %%
u = hf.low_frequency_signal()

# %%
u.autocorrelation
# Out:
# U**2*exp(-Abs(tau)/T)

# %%
u.spectrum
# Out:
# 2*T*U**2/(T**2*omega**2 + 1)

# %%
u.plot_spectrum(label='T_l=10d')
# for multiple parameter values:
#E = u.evaluate_spectrum()
#E

if print_figs:
    plt.savefig('overview_low_spectrum.png')

# %%
u_syn = u.generate_tseries()
u_syn.plot()

if print_figs:
    plt.savefig('figs/overview_low_tseries.png')

# %%
R = ts.correlate(u_syn, u_syn)
R.plot()
R
# Out:
# <xarray.DataArray 'low_low' (lags: 1200)>
# dask.array<correlate, shape=(1200,), dtype=float64, chunksize=(1200,), chunktype=numpy.ndarray>
# Coordinates:
#   * lags     (lags) float64 0.0 0.04167 0.08333 0.125 ... 49.88 49.92 49.96
